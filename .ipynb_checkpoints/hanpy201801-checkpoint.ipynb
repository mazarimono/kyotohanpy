# %%
import requests
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import show, figure
from datetime import datetime
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="df195088-8868-4075-b02b-bd6520d06d4e">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## wavesplatformのAPIを使ってみる！
# #### wavesとは？？？
# https://wavesplatform.com/
# * 暗号通貨、仮想通貨
# * DEX（分散型取引所）を運営したりするプロジェクト
# * ちょっと前からDEXは動いている。デトロイトとICOの規制を作ったりしているが、日本の取引所では
#   取り扱われていないため今ひとつマイナー。
# * 世界各国で取引所が規制される流れとなっているが、今年はどんどんDEXが動き始め、そんなの気にしない
#   という流れとなるであろう。逆に、取引所はそうなる前に現金化を急ぐ。zaifはとっととicoで逃げ切り、
#   BitflyerはIPOを急いでいる。
# * 現在の取引所のシステムは一箇所にリスクが集中している。取引所が攻撃され、仮想通貨が盗られる場合がある。
# 一方、DEXだと分散して記録が残るので、データの書き換えが難しく、そのへんが難しくなるのかもしれないなぁと
#   期待している。
#
# #### wavesのDEXのAPIを使いながらどんな感じかみてみよう。
# http://marketdata.wavesplatform.com/

# %%
address = 'https://marketdata.wavesplatform.com/api/'

# %%
r = requests.get(address+'symbols').json()

# %%
r[0:5]
# Out:
# [{'assetID': '2LU8GwJFvVebrCvgDhMTLDzm3dHxuN1x7ks8dQRiSj9N', 'symbol': '2B4T'},
#  {'assetID': '9UFoSQSZZU5j8au1cLYgJGNNtuXAc2s1C4Xd8sPimqL8', 'symbol': 'AFFT'},
#  {'assetID': 'J8mgyjKQb4M7DjEKvewBSvKZULMZMDpUtua9VtByLbVD', 'symbol': 'AGRO'},
#  {'assetID': 'HfFHZaPzGMSdHvaaZ7S8mrZrPWEyGzfA6VDuSRzb8uY6', 'symbol': 'AHT'},
#  {'assetID': '3ihiQ1TJhe7fBrMc8o9EY8tQNU6phkmp8ZEyvVe4Jfhk',
#   'symbol': 'AKCHE'}]

# %%
len(r)
# Out:
# 200

# %%
symbols = []
for i in r:
    symbols.append(i['symbol'])

# %%
symbols[:5]
# Out:
# ['2B4T', 'AFFT', 'AGRO', 'AHT', 'AKCHE']

# %%
# 24時間の動向
r1 = requests.get(address+'markets').json()

# %%
r1[100]
# Out:
# {'24h_close': '0.00000425',
#  '24h_high': '0.00000530',
#  '24h_low': '0.00000350',
#  '24h_open': '0.00000360',
#  '24h_priceVolume': '0.48272022',
#  '24h_volume': '123457.85858031',
#  '24h_vwap': '0.00000391',
#  'amountAssetCirculatingSupply': '49995673.00000000',
#  'amountAssetDecimals': 8,
#  'amountAssetID': 'GdnNbe6E3txF63gv3rxhpfxytTJtG7ZYyHAvWWrrEbK5',
#  'amountAssetMaxSupply': '100000000.00000000',
#  'amountAssetName': 'EOT Token',
#  'amountAssetTotalSupply': '100000000.00000000',
#  'firstTradeDay': 1499126400000,
#  'lastTradeDay': 1499126743872,
#  'priceAssetCirculatingSupply': '2769.00000000',
#  'priceAssetDecimals': 8,
#  'priceAssetID': '8LQW8f7P5d5PZM7GtZEBgaqRPGSzS3DfPuiXrURJ4AJS',
#  'priceAssetMaxSupply': '21000000.00000000',
#  'priceAssetName': 'WBTC',
#  'priceAssetTotalSupply': '21000000.00000000',
#  'symbol': 'EOT/BTC',
#  'totalTrades': 22814}

# %%
amount = []
for i in range(len(r1)):
    amount.append(float(r1[i]['24h_vwap']) * float(r1[i]['24h_volume']))

# %%
sum(amount)
# Out:
# 1060435.7091624355

# %%
r2 = requests.get(address+'tickers').json()

# %%
r2[100]
# Out:
# {'24h_close': '0.00000425',
#  '24h_high': '0.00000530',
#  '24h_low': '0.00000350',
#  '24h_open': '0.00000360',
#  '24h_priceVolume': '0.48272022',
#  '24h_volume': '123457.85858031',
#  '24h_vwap': '0.00000391',
#  'amountAssetCirculatingSupply': '49995673.00000000',
#  'amountAssetDecimals': 8,
#  'amountAssetID': 'GdnNbe6E3txF63gv3rxhpfxytTJtG7ZYyHAvWWrrEbK5',
#  'amountAssetMaxSupply': '100000000.00000000',
#  'amountAssetName': 'EOT Token',
#  'amountAssetTotalSupply': '100000000.00000000',
#  'priceAssetCirculatingSupply': '2769.00000000',
#  'priceAssetDecimals': 8,
#  'priceAssetID': '8LQW8f7P5d5PZM7GtZEBgaqRPGSzS3DfPuiXrURJ4AJS',
#  'priceAssetMaxSupply': '21000000.00000000',
#  'priceAssetName': 'WBTC',
#  'priceAssetTotalSupply': '21000000.00000000',
#  'symbol': 'EOT/BTC',
#  'timestamp': 1516347194773}

# %%
len(r2)
# Out:
# 3022

# %%
r2[2000]
# Out:
# {'24h_close': '0.00000000',
#  '24h_high': '0.00000000',
#  '24h_low': '0.00000000',
#  '24h_open': '0.00000000',
#  '24h_priceVolume': '0.00000000',
#  '24h_volume': '0.00000',
#  '24h_vwap': '0.00000000',
#  'amountAssetCirculatingSupply': '750094006.00000',
#  'amountAssetDecimals': 5,
#  'amountAssetID': 'BvQbMQ2g52dZpZUcu2syaedqFajUFhTpb5wHc35DprZN',
#  'amountAssetMaxSupply': '1000000000.00000',
#  'amountAssetName': 'Sestertius',
#  'amountAssetTotalSupply': '1000000000.00000',
#  'priceAssetCirculatingSupply': '2769.00000',
#  'priceAssetDecimals': 8,
#  'priceAssetID': '8LQW8f7P5d5PZM7GtZEBgaqRPGSzS3DfPuiXrURJ4AJS',
#  'priceAssetMaxSupply': '21000000.00000',
#  'priceAssetName': 'WBTC',
#  'priceAssetTotalSupply': '21000000.00000',
#  'symbol': '',
#  'timestamp': 1516347194908}

# %%
r3 = requests.get(address+'ticker/WAVES/BTC').json()

# %%
r3
# Out:
# {'24h_close': '0.00073467',
#  '24h_high': '0.00076263',
#  '24h_low': '0.00071000',
#  '24h_open': '0.00071810',
#  '24h_priceVolume': '50.63756212',
#  '24h_volume': '68330.33603900',
#  '24h_vwap': '0.00074107',
#  'amountAssetCirculatingSupply': '100000000.00000000',
#  'amountAssetDecimals': 8,
#  'amountAssetID': 'WAVES',
#  'amountAssetMaxSupply': '100000000.00000000',
#  'amountAssetName': 'WAVES',
#  'amountAssetTotalSupply': '100000000.00000000',
#  'priceAssetCirculatingSupply': '2769.00000000',
#  'priceAssetDecimals': 8,
#  'priceAssetID': '8LQW8f7P5d5PZM7GtZEBgaqRPGSzS3DfPuiXrURJ4AJS',
#  'priceAssetMaxSupply': '21000000.00000000',
#  'priceAssetName': 'WBTC',
#  'priceAssetTotalSupply': '21000000.00000000',
#  'symbol': 'WAVES/BTC',
#  'timestamp': 1516347211494}

# %%
r4 = requests.get(address+'ticker/ZEC/BTC').json()

# %%
r4
# Out:
# {'24h_close': '0.04498882',
#  '24h_high': '0.04498882',
#  '24h_low': '0.04200001',
#  '24h_open': '0.04487450',
#  '24h_priceVolume': '0.13808103',
#  '24h_volume': '3.19100272',
#  '24h_vwap': '0.04327199',
#  'amountAssetCirculatingSupply': '1300.00000000',
#  'amountAssetDecimals': 8,
#  'amountAssetID': 'BrjUWjndUanm5VsJkbUip8VRYy6LWJePtxya3FNv4TQa',
#  'amountAssetMaxSupply': '21000000.00000000',
#  'amountAssetName': 'Zcash',
#  'amountAssetTotalSupply': '21000000.00000000',
#  'priceAssetCirculatingSupply': '2769.00000000',
#  'priceAssetDecimals': 8,
#  'priceAssetID': '8LQW8f7P5d5PZM7GtZEBgaqRPGSzS3DfPuiXrURJ4AJS',
#  'priceAssetMaxSupply': '21000000.00000000',
#  'priceAssetName': 'WBTC',
#  'priceAssetTotalSupply': '21000000.00000000',
#  'symbol': 'ZEC/BTC',
#  'timestamp': 1516347213017}

# %%
r5 = requests.get(address+'ticker/ETH/BTC').json()

# %%
r5
# Out:
# {'24h_close': '0.09075139',
#  '24h_high': '0.09272914',
#  '24h_low': '0.08780000',
#  '24h_open': '0.08781000',
#  '24h_priceVolume': '6.84226052',
#  '24h_volume': '75.41348838',
#  '24h_vwap': '0.09072993',
#  'amountAssetCirculatingSupply': '5944.00000000',
#  'amountAssetDecimals': 8,
#  'amountAssetID': '474jTeYx2r2Va35794tCScAXWJG9hU2HcgxzMowaZUnu',
#  'amountAssetMaxSupply': 'infinite',
#  'amountAssetName': 'WETH',
#  'amountAssetTotalSupply': '100000000.00000000',
#  'priceAssetCirculatingSupply': '2769.00000000',
#  'priceAssetDecimals': 8,
#  'priceAssetID': '8LQW8f7P5d5PZM7GtZEBgaqRPGSzS3DfPuiXrURJ4AJS',
#  'priceAssetMaxSupply': '21000000.00000000',
#  'priceAssetName': 'WBTC',
#  'priceAssetTotalSupply': '21000000.00000000',
#  'symbol': 'ETH/BTC',
#  'timestamp': 1516347220477}

# %%
r6 = requests.get(address + 'trades/WAVES/BTC/3').json()

# %%
r6
# Out:
# [{'amount': '87.90324640',
#   'buyer': '3P65FUFxRybbPmFpbGYVnTCRVfmCCh4zfuB',
#   'confirmed': True,
#   'id': '4Z32Q3REpSsvs3FuVK4WvwRukPtzoCwAajniAGQj2VPb',
#   'matcher': '7kPFrHDiGw1rCm7LPszuECwWYL3dMf6iMifLRDJQZMzy',
#   'price': '0.00073467',
#   'seller': '3PCTvRs4cPMsn57b9SnRQU1TQuNFEDv7um8',
#   'timestamp': 1516347118517,
#   'type': 'buy'},
#  {'amount': '29.49796775',
#   'buyer': '3P65FUFxRybbPmFpbGYVnTCRVfmCCh4zfuB',
#   'confirmed': True,
#   'id': '87ZPCTJVpB58ZBqPX2fsER2TvuqZc2t59kDSEeEYjhLv',
#   'matcher': '7kPFrHDiGw1rCm7LPszuECwWYL3dMf6iMifLRDJQZMzy',
#   'price': '0.00073164',
#   'seller': '3PPAywuVbFTJiWftutNmRV5BrdJqBPd61yt',
#   'timestamp': 1516347118513,
#   'type': 'buy'},
#  {'amount': '26.57075430',
#   'buyer': '3PCkPVvDJZBFbmSR6sp149bd63u62RFxaC3',
#   'confirmed': True,
#   'id': '2ZJNpf3dauPbDng5cMqUwawb2L8Ne3vhttMvBtkDf9GJ',
#   'matcher': '7kPFrHDiGw1rCm7LPszuECwWYL3dMf6iMifLRDJQZMzy',
#   'price': '0.00072938',
#   'seller': '3PNNzRNhXXqHQyVKncxY2yLAVtP8K2983Hp',
#   'timestamp': 1516347112668,
#   'type': 'buy'}]

# %%
r7 = requests.get(address+'candles/WAVES/BTC/5/100').json()

# %%
r7
# Out:
# [{'close': '0.00073544',
#   'confirmed': True,
#   'high': '0.00073544',
#   'low': '0.00073443',
#   'open': '0.00073443',
#   'priceVolume': '0.01451969',
#   'timestamp': 1516344300000,
#   'volume': '19.75495240',
#   'vwap': '0.00073499'},
#  {'close': '0.00073309',
#   'confirmed': True,
#   'high': '0.00073309',
#   'low': '0.00073309',
#   'open': '0.00073309',
#   'priceVolume': '0.07330282',
#   'timestamp': 1516344000000,
#   'volume': '99.99158357',
#   'vwap': '0.00073309'},
#  {'close': '0.00073201',
#   'confirmed': True,
#   'high': '0.00073201',
#   'low': '0.00073201',
#   'open': '0.00073201',
#   'priceVolume': '0.00991107',
#   'timestamp': 1516343700000,
#   'volume': '13.53952995',
#   'vwap': '0.00073201'},
#  {'close': '0.00073284',
#   'confirmed': True,
#   'high': '0.00073284',
#   'low': '0.00073284',
#   'open': '0.00073284',
#   'priceVolume': '0.00018995',
#   'timestamp': 1516343400000,
#   'volume': '0.25920745',
#   'vwap': '0.00073284'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516343100000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516342800000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516342500000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00073128',
#   'confirmed': True,
#   'high': '0.00073266',
#   'low': '0.00073128',
#   'open': '0.00073266',
#   'priceVolume': '0.04709781',
#   'timestamp': 1516342200000,
#   'volume': '64.28683098',
#   'vwap': '0.00073262'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516341900000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00073430',
#   'confirmed': True,
#   'high': '0.00073430',
#   'low': '0.00072641',
#   'open': '0.00072641',
#   'priceVolume': '0.00218702',
#   'timestamp': 1516341600000,
#   'volume': '2.98917097',
#   'vwap': '0.00073165'},
#  {'close': '0.00072620',
#   'confirmed': True,
#   'high': '0.00073000',
#   'low': '0.00072620',
#   'open': '0.00073000',
#   'priceVolume': '0.13424130',
#   'timestamp': 1516341300000,
#   'volume': '184.28095855',
#   'vwap': '0.00072846'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516341000000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00073555',
#   'confirmed': True,
#   'high': '0.00073555',
#   'low': '0.00073068',
#   'open': '0.00073068',
#   'priceVolume': '0.17152005',
#   'timestamp': 1516340700000,
#   'volume': '233.67536981',
#   'vwap': '0.00073401'},
#  {'close': '0.00073375',
#   'confirmed': True,
#   'high': '0.00073375',
#   'low': '0.00073375',
#   'open': '0.00073375',
#   'priceVolume': '0.01498225',
#   'timestamp': 1516340400000,
#   'volume': '20.41875298',
#   'vwap': '0.00073375'},
#  {'close': '0.00073479',
#   'confirmed': True,
#   'high': '0.00073479',
#   'low': '0.00073479',
#   'open': '0.00073479',
#   'priceVolume': '0.00073479',
#   'timestamp': 1516340100000,
#   'volume': '1.00000000',
#   'vwap': '0.00073479'},
#  {'close': '0.00073463',
#   'confirmed': True,
#   'high': '0.00073463',
#   'low': '0.00073463',
#   'open': '0.00073463',
#   'priceVolume': '0.32527107',
#   'timestamp': 1516339800000,
#   'volume': '442.76856866',
#   'vwap': '0.00073463'},
#  {'close': '0.00073675',
#   'confirmed': True,
#   'high': '0.00073675',
#   'low': '0.00072900',
#   'open': '0.00072900',
#   'priceVolume': '0.10992360',
#   'timestamp': 1516339500000,
#   'volume': '150.32492975',
#   'vwap': '0.00073124'},
#  {'close': '0.00073035',
#   'confirmed': True,
#   'high': '0.00073035',
#   'low': '0.00073035',
#   'open': '0.00073035',
#   'priceVolume': '0.00146070',
#   'timestamp': 1516339200000,
#   'volume': '2.00000000',
#   'vwap': '0.00073035'},
#  {'close': '0.00073149',
#   'confirmed': True,
#   'high': '0.00073290',
#   'low': '0.00073149',
#   'open': '0.00073211',
#   'priceVolume': '0.27573811',
#   'timestamp': 1516338900000,
#   'volume': '376.54223571',
#   'vwap': '0.00073229'},
#  {'close': '0.00073246',
#   'confirmed': True,
#   'high': '0.00073246',
#   'low': '0.00072300',
#   'open': '0.00072774',
#   'priceVolume': '0.59487996',
#   'timestamp': 1516338600000,
#   'volume': '814.91522757',
#   'vwap': '0.00072999'},
#  {'close': '0.00073180',
#   'confirmed': True,
#   'high': '0.00073180',
#   'low': '0.00072661',
#   'open': '0.00072661',
#   'priceVolume': '0.20345435',
#   'timestamp': 1516338300000,
#   'volume': '279.29761953',
#   'vwap': '0.00072845'},
#  {'close': '0.00072766',
#   'confirmed': True,
#   'high': '0.00073329',
#   'low': '0.00072766',
#   'open': '0.00073329',
#   'priceVolume': '0.11742201',
#   'timestamp': 1516338000000,
#   'volume': '160.22871833',
#   'vwap': '0.00073284'},
#  {'close': '0.00073220',
#   'confirmed': True,
#   'high': '0.00073220',
#   'low': '0.00072342',
#   'open': '0.00072523',
#   'priceVolume': '0.17125844',
#   'timestamp': 1516337700000,
#   'volume': '236.05249266',
#   'vwap': '0.00072551'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516337400000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00072651',
#   'confirmed': True,
#   'high': '0.00072651',
#   'low': '0.00072651',
#   'open': '0.00072651',
#   'priceVolume': '0.10800002',
#   'timestamp': 1516337100000,
#   'volume': '148.65594417',
#   'vwap': '0.00072651'},
#  {'close': '0.00072416',
#   'confirmed': True,
#   'high': '0.00072434',
#   'low': '0.00072416',
#   'open': '0.00072434',
#   'priceVolume': '0.03932592',
#   'timestamp': 1516336800000,
#   'volume': '54.29883279',
#   'vwap': '0.00072425'},
#  {'close': '0.00072225',
#   'confirmed': True,
#   'high': '0.00072801',
#   'low': '0.00072225',
#   'open': '0.00072801',
#   'priceVolume': '0.41239315',
#   'timestamp': 1516336500000,
#   'volume': '568.59855003',
#   'vwap': '0.00072528'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516336200000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00073204',
#   'confirmed': True,
#   'high': '0.00073204',
#   'low': '0.00073082',
#   'open': '0.00073204',
#   'priceVolume': '0.11651277',
#   'timestamp': 1516335900000,
#   'volume': '159.19873161',
#   'vwap': '0.00073187'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516335600000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00072801',
#   'confirmed': True,
#   'high': '0.00072984',
#   'low': '0.00072801',
#   'open': '0.00072984',
#   'priceVolume': '0.04857806',
#   'timestamp': 1516335300000,
#   'volume': '66.60734429',
#   'vwap': '0.00072932'},
#  {'close': '0.00072801',
#   'confirmed': True,
#   'high': '0.00072801',
#   'low': '0.00072801',
#   'open': '0.00072801',
#   'priceVolume': '0.00582408',
#   'timestamp': 1516335000000,
#   'volume': '8.00000000',
#   'vwap': '0.00072801'},
#  {'close': '0.00073199',
#   'confirmed': True,
#   'high': '0.00073199',
#   'low': '0.00073199',
#   'open': '0.00073199',
#   'priceVolume': '0.01829975',
#   'timestamp': 1516334700000,
#   'volume': '25.00000000',
#   'vwap': '0.00073199'},
#  {'close': '0.00073104',
#   'confirmed': True,
#   'high': '0.00073199',
#   'low': '0.00073104',
#   'open': '0.00073195',
#   'priceVolume': '0.08929757',
#   'timestamp': 1516334400000,
#   'volume': '122.02622442',
#   'vwap': '0.00073179'},
#  {'close': '0.00073199',
#   'confirmed': True,
#   'high': '0.00073199',
#   'low': '0.00073199',
#   'open': '0.00073199',
#   'priceVolume': '0.00073199',
#   'timestamp': 1516334100000,
#   'volume': '1.00000000',
#   'vwap': '0.00073199'},
#  {'close': '0.00072801',
#   'confirmed': True,
#   'high': '0.00072900',
#   'low': '0.00072801',
#   'open': '0.00072900',
#   'priceVolume': '0.06463624',
#   'timestamp': 1516333800000,
#   'volume': '88.72511977',
#   'vwap': '0.00072850'},
#  {'close': '0.00072900',
#   'confirmed': True,
#   'high': '0.00073000',
#   'low': '0.00072900',
#   'open': '0.00073000',
#   'priceVolume': '0.00948896',
#   'timestamp': 1516333500000,
#   'volume': '13.00000000',
#   'vwap': '0.00072992'},
#  {'close': '0.00073176',
#   'confirmed': True,
#   'high': '0.00073176',
#   'low': '0.00073104',
#   'open': '0.00073104',
#   'priceVolume': '0.24798967',
#   'timestamp': 1516333200000,
#   'volume': '339.14508855',
#   'vwap': '0.00073122'},
#  {'close': '0.00073010',
#   'confirmed': True,
#   'high': '0.00073200',
#   'low': '0.00073010',
#   'open': '0.00073200',
#   'priceVolume': '0.17251397',
#   'timestamp': 1516332900000,
#   'volume': '235.77146174',
#   'vwap': '0.00073170'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516332600000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00073688',
#   'confirmed': True,
#   'high': '0.00073697',
#   'low': '0.00073073',
#   'open': '0.00073254',
#   'priceVolume': '0.13341211',
#   'timestamp': 1516332300000,
#   'volume': '181.46123728',
#   'vwap': '0.00073521'},
#  {'close': '0.00073715',
#   'confirmed': True,
#   'high': '0.00073715',
#   'low': '0.00073010',
#   'open': '0.00073686',
#   'priceVolume': '0.09944905',
#   'timestamp': 1516332000000,
#   'volume': '135.45226974',
#   'vwap': '0.00073420'},
#  {'close': '0.00073113',
#   'confirmed': True,
#   'high': '0.00073716',
#   'low': '0.00073113',
#   'open': '0.00073425',
#   'priceVolume': '0.31758239',
#   'timestamp': 1516331700000,
#   'volume': '432.36136527',
#   'vwap': '0.00073453'},
#  {'close': '0.00073425',
#   'confirmed': True,
#   'high': '0.00073425',
#   'low': '0.00073425',
#   'open': '0.00073425',
#   'priceVolume': '0.00146850',
#   'timestamp': 1516331400000,
#   'volume': '2.00000000',
#   'vwap': '0.00073425'},
#  {'close': '0.00073425',
#   'confirmed': True,
#   'high': '0.00073425',
#   'low': '0.00073425',
#   'open': '0.00073425',
#   'priceVolume': '0.03695000',
#   'timestamp': 1516331100000,
#   'volume': '50.32347293',
#   'vwap': '0.00073425'},
#  {'close': '0.00073900',
#   'confirmed': True,
#   'high': '0.00073900',
#   'low': '0.00073010',
#   'open': '0.00073401',
#   'priceVolume': '0.14800240',
#   'timestamp': 1516330800000,
#   'volume': '201.65738596',
#   'vwap': '0.00073393'},
#  {'close': '0.00074147',
#   'confirmed': True,
#   'high': '0.00074168',
#   'low': '0.00074147',
#   'open': '0.00074168',
#   'priceVolume': '0.17088177',
#   'timestamp': 1516330500000,
#   'volume': '230.40756874',
#   'vwap': '0.00074165'},
#  {'close': '0.00074147',
#   'confirmed': True,
#   'high': '0.00074147',
#   'low': '0.00073800',
#   'open': '0.00073800',
#   'priceVolume': '0.22223100',
#   'timestamp': 1516330200000,
#   'volume': '300.00000000',
#   'vwap': '0.00074077'},
#  {'close': '0.00073210',
#   'confirmed': True,
#   'high': '0.00073210',
#   'low': '0.00073010',
#   'open': '0.00073200',
#   'priceVolume': '0.08172619',
#   'timestamp': 1516329900000,
#   'volume': '111.70579155',
#   'vwap': '0.00073162'},
#  {'close': '0.00073210',
#   'confirmed': True,
#   'high': '0.00073210',
#   'low': '0.00073200',
#   'open': '0.00073210',
#   'priceVolume': '0.06392962',
#   'timestamp': 1516329600000,
#   'volume': '87.32481477',
#   'vwap': '0.00073209'},
#  {'close': '0.00073210',
#   'confirmed': True,
#   'high': '0.00073242',
#   'low': '0.00073210',
#   'open': '0.00073242',
#   'priceVolume': '0.14642000',
#   'timestamp': 1516329300000,
#   'volume': '200.00000000',
#   'vwap': '0.00073210'},
#  {'close': '0.00073800',
#   'confirmed': True,
#   'high': '0.00073921',
#   'low': '0.00073242',
#   'open': '0.00073921',
#   'priceVolume': '0.10708770',
#   'timestamp': 1516329000000,
#   'volume': '145.93781397',
#   'vwap': '0.00073379'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516328700000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00073242',
#   'confirmed': True,
#   'high': '0.00073615',
#   'low': '0.00073242',
#   'open': '0.00073615',
#   'priceVolume': '0.11606430',
#   'timestamp': 1516328400000,
#   'volume': '157.87625699',
#   'vwap': '0.00073516'},
#  {'close': '0.00073628',
#   'confirmed': True,
#   'high': '0.00073954',
#   'low': '0.00073628',
#   'open': '0.00073733',
#   'priceVolume': '0.07703659',
#   'timestamp': 1516328100000,
#   'volume': '104.58970555',
#   'vwap': '0.00073656'},
#  {'close': '0.00073891',
#   'confirmed': True,
#   'high': '0.00073891',
#   'low': '0.00073891',
#   'open': '0.00073891',
#   'priceVolume': '0.00443346',
#   'timestamp': 1516327800000,
#   'volume': '6.00000000',
#   'vwap': '0.00073891'},
#  {'close': '0.00073954',
#   'confirmed': True,
#   'high': '0.00073954',
#   'low': '0.00073954',
#   'open': '0.00073954',
#   'priceVolume': '0.05249999',
#   'timestamp': 1516327500000,
#   'volume': '70.99007491',
#   'vwap': '0.00073954'},
#  {'close': '0.00074019',
#   'confirmed': True,
#   'high': '0.00074019',
#   'low': '0.00074019',
#   'open': '0.00074019',
#   'priceVolume': '0.07401900',
#   'timestamp': 1516327200000,
#   'volume': '100.00000000',
#   'vwap': '0.00074019'},
#  {'close': '0.00073600',
#   'confirmed': True,
#   'high': '0.00073600',
#   'low': '0.00073600',
#   'open': '0.00073600',
#   'priceVolume': '0.00007360',
#   'timestamp': 1516326900000,
#   'volume': '0.10000000',
#   'vwap': '0.00073600'},
#  {'close': '0.00073650',
#   'confirmed': True,
#   'high': '0.00074311',
#   'low': '0.00073650',
#   'open': '0.00074311',
#   'priceVolume': '0.41179851',
#   'timestamp': 1516326600000,
#   'volume': '555.19402714',
#   'vwap': '0.00074172'},
#  {'close': '0.00074311',
#   'confirmed': True,
#   'high': '0.00074311',
#   'low': '0.00073652',
#   'open': '0.00073652',
#   'priceVolume': '0.05806682',
#   'timestamp': 1516326300000,
#   'volume': '78.58442990',
#   'vwap': '0.00073891'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516326000000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00074080',
#   'confirmed': True,
#   'high': '0.00074080',
#   'low': '0.00073651',
#   'open': '0.00073746',
#   'priceVolume': '0.58332812',
#   'timestamp': 1516325700000,
#   'volume': '790.32113412',
#   'vwap': '0.00073809'},
#  {'close': '0.00073746',
#   'confirmed': True,
#   'high': '0.00074149',
#   'low': '0.00073255',
#   'open': '0.00073938',
#   'priceVolume': '0.39356023',
#   'timestamp': 1516325400000,
#   'volume': '532.67315874',
#   'vwap': '0.00073884'},
#  {'close': '0.00073255',
#   'confirmed': True,
#   'high': '0.00073913',
#   'low': '0.00073255',
#   'open': '0.00073913',
#   'priceVolume': '0.19393883',
#   'timestamp': 1516325100000,
#   'volume': '264.61480389',
#   'vwap': '0.00073291'},
#  {'close': '0.00073981',
#   'confirmed': True,
#   'high': '0.00074770',
#   'low': '0.00073302',
#   'open': '0.00074657',
#   'priceVolume': '0.60687779',
#   'timestamp': 1516324800000,
#   'volume': '823.16417815',
#   'vwap': '0.00073725'},
#  {'close': '0.00074481',
#   'confirmed': True,
#   'high': '0.00074481',
#   'low': '0.00074481',
#   'open': '0.00074481',
#   'priceVolume': '0.02127238',
#   'timestamp': 1516324500000,
#   'volume': '28.56082496',
#   'vwap': '0.00074481'},
#  {'close': '0.00074114',
#   'confirmed': True,
#   'high': '0.00074114',
#   'low': '0.00074114',
#   'open': '0.00074114',
#   'priceVolume': '0.06715710',
#   'timestamp': 1516324200000,
#   'volume': '90.61325726',
#   'vwap': '0.00074114'},
#  {'close': '0.00074364',
#   'confirmed': True,
#   'high': '0.00074364',
#   'low': '0.00074364',
#   'open': '0.00074364',
#   'priceVolume': '0.00371820',
#   'timestamp': 1516323900000,
#   'volume': '5.00000000',
#   'vwap': '0.00074364'},
#  {'close': '0.00073800',
#   'confirmed': True,
#   'high': '0.00074396',
#   'low': '0.00073749',
#   'open': '0.00074131',
#   'priceVolume': '0.13749503',
#   'timestamp': 1516323600000,
#   'volume': '185.07132385',
#   'vwap': '0.00074293'},
#  {'close': '0.00074456',
#   'confirmed': True,
#   'high': '0.00074509',
#   'low': '0.00074131',
#   'open': '0.00074509',
#   'priceVolume': '0.07953303',
#   'timestamp': 1516323300000,
#   'volume': '106.87195195',
#   'vwap': '0.00074419'},
#  {'close': '0.00074509',
#   'confirmed': True,
#   'high': '0.00074509',
#   'low': '0.00074509',
#   'open': '0.00074509',
#   'priceVolume': '0.40914861',
#   'timestamp': 1516323000000,
#   'volume': '549.12644110',
#   'vwap': '0.00074509'},
#  {'close': '0.00074377',
#   'confirmed': True,
#   'high': '0.00074509',
#   'low': '0.00074377',
#   'open': '0.00074509',
#   'priceVolume': '0.11582239',
#   'timestamp': 1516322700000,
#   'volume': '155.61251050',
#   'vwap': '0.00074430'},
#  {'close': '0.00074509',
#   'confirmed': True,
#   'high': '0.00074562',
#   'low': '0.00074508',
#   'open': '0.00074562',
#   'priceVolume': '0.06859822',
#   'timestamp': 1516322400000,
#   'volume': '92.05714340',
#   'vwap': '0.00074517'},
#  {'close': '0.00074542',
#   'confirmed': True,
#   'high': '0.00074542',
#   'low': '0.00074504',
#   'open': '0.00074504',
#   'priceVolume': '0.14390474',
#   'timestamp': 1516322100000,
#   'volume': '193.09593061',
#   'vwap': '0.00074525'},
#  {'close': '0.00073440',
#   'confirmed': True,
#   'high': '0.00073440',
#   'low': '0.00073440',
#   'open': '0.00073440',
#   'priceVolume': '0.73440000',
#   'timestamp': 1516321800000,
#   'volume': '1000.00000000',
#   'vwap': '0.00073440'},
#  {'close': '0.00073900',
#   'confirmed': True,
#   'high': '0.00073900',
#   'low': '0.00073900',
#   'open': '0.00073900',
#   'priceVolume': '0.04849999',
#   'timestamp': 1516321500000,
#   'volume': '65.62922868',
#   'vwap': '0.00073900'},
#  {'close': '0.00073900',
#   'confirmed': True,
#   'high': '0.00073930',
#   'low': '0.00073420',
#   'open': '0.00073878',
#   'priceVolume': '0.67005061',
#   'timestamp': 1516321200000,
#   'volume': '907.74315703',
#   'vwap': '0.00073815'},
#  {'close': '0.00073930',
#   'confirmed': True,
#   'high': '0.00074000',
#   'low': '0.00073930',
#   'open': '0.00074000',
#   'priceVolume': '0.13172278',
#   'timestamp': 1516320900000,
#   'volume': '178.03263509',
#   'vwap': '0.00073988'},
#  {'close': '0.00074563',
#   'confirmed': True,
#   'high': '0.00074563',
#   'low': '0.00074563',
#   'open': '0.00074563',
#   'priceVolume': '0.07881203',
#   'timestamp': 1516320600000,
#   'volume': '105.69859045',
#   'vwap': '0.00074563'},
#  {'close': '0.00000000',
#   'confirmed': True,
#   'high': '0.00000000',
#   'low': '0.00000000',
#   'open': '0.00000000',
#   'priceVolume': '0.00000000',
#   'timestamp': 1516320300000,
#   'volume': '0.00000000',
#   'vwap': '0.00000000'},
#  {'close': '0.00074232',
#   'confirmed': True,
#   'high': '0.00074232',
#   'low': '0.00074232',
#   'open': '0.00074232',
#   'priceVolume': '0.00012599',
#   'timestamp': 1516320000000,
#   'volume': '0.16973321',
#   'vwap': '0.00074232'},
#  {'close': '0.00073800',
#   'confirmed': True,
#   'high': '0.00073800',
#   'low': '0.00073800',
#   'open': '0.00073800',
#   'priceVolume': '0.07896600',
#   'timestamp': 1516319700000,
#   'volume': '107.00000000',
#   'vwap': '0.00073800'},
#  {'close': '0.00074205',
#   'confirmed': True,
#   'high': '0.00074205',
#   'low': '0.00073700',
#   'open': '0.00073983',
#   'priceVolume': '0.18822863',
#   'timestamp': 1516319400000,
#   'volume': '254.07118119',
#   'vwap': '0.00074085'},
#  {'close': '0.00073983',
#   'confirmed': True,
#   'high': '0.00074074',
#   'low': '0.00073983',
#   'open': '0.00074074',
#   'priceVolume': '0.01584374',
#   'timestamp': 1516319100000,
#   'volume': '21.40525815',
#   'vwap': '0.00074018'},
#  {'close': '0.00074485',
#   'confirmed': True,
#   'high': '0.00074521',
#   'low': '0.00074307',
#   'open': '0.00074307',
#   'priceVolume': '0.23615480',
#   'timestamp': 1516318800000,
#   'volume': '317.56176411',
#   'vwap': '0.00074365'},
#  {'close': '0.00073822',
#   'confirmed': True,
#   'high': '0.00073822',
#   'low': '0.00073420',
#   'open': '0.00073820',
#   'priceVolume': '1.49022919',
#   'timestamp': 1516318500000,
#   'volume': '2028.07456939',
#   'vwap': '0.00073480'},
#  {'close': '0.00073988',
#   'confirmed': True,
#   'high': '0.00074679',
#   'low': '0.00073988',
#   'open': '0.00074550',
#   'priceVolume': '0.43183807',
#   'timestamp': 1516318200000,
#   'volume': '582.80889254',
#   'vwap': '0.00074096'},
#  {'close': '0.00074042',
#   'confirmed': True,
#   'high': '0.00074042',
#   'low': '0.00074042',
#   'open': '0.00074042',
#   'priceVolume': '0.00148084',
#   'timestamp': 1516317900000,
#   'volume': '2.00000000',
#   'vwap': '0.00074042'},
#  {'close': '0.00074764',
#   'confirmed': True,
#   'high': '0.00074764',
#   'low': '0.00074764',
#   'open': '0.00074764',
#   'priceVolume': '0.14952800',
#   'timestamp': 1516317600000,
#   'volume': '200.00000000',
#   'vwap': '0.00074764'},
#  {'close': '0.00074042',
#   'confirmed': True,
#   'high': '0.00074050',
#   'low': '0.00074042',
#   'open': '0.00074050',
#   'priceVolume': '0.00971824',
#   'timestamp': 1516317300000,
#   'volume': '13.12495734',
#   'vwap': '0.00074044'},
#  {'close': '0.00074765',
#   'confirmed': True,
#   'high': '0.00074765',
#   'low': '0.00074150',
#   'open': '0.00074150',
#   'priceVolume': '0.21221870',
#   'timestamp': 1516317000000,
#   'volume': '283.87803932',
#   'vwap': '0.00074757'},
#  {'close': '0.00074259',
#   'confirmed': True,
#   'high': '0.00074770',
#   'low': '0.00074259',
#   'open': '0.00074770',
#   'priceVolume': '0.22658320',
#   'timestamp': 1516316700000,
#   'volume': '303.37703434',
#   'vwap': '0.00074687'},
#  {'close': '0.00074042',
#   'confirmed': True,
#   'high': '0.00074454',
#   'low': '0.00074042',
#   'open': '0.00074200',
#   'priceVolume': '0.60382269',
#   'timestamp': 1516316400000,
#   'volume': '813.86495884',
#   'vwap': '0.00074192'},
#  {'close': '0.00074459',
#   'confirmed': True,
#   'high': '0.00074593',
#   'low': '0.00074265',
#   'open': '0.00074265',
#   'priceVolume': '0.11670607',
#   'timestamp': 1516316100000,
#   'volume': '156.71344976',
#   'vwap': '0.00074471'},
#  {'close': '0.00074265',
#   'confirmed': True,
#   'high': '0.00074770',
#   'low': '0.00074265',
#   'open': '0.00074770',
#   'priceVolume': '0.11413052',
#   'timestamp': 1516315800000,
#   'volume': '153.44661078',
#   'vwap': '0.00074378'},
#  {'close': '0.00074507',
#   'confirmed': True,
#   'high': '0.00074770',
#   'low': '0.00074182',
#   'open': '0.00074770',
#   'priceVolume': '0.79418626',
#   'timestamp': 1516315500000,
#   'volume': '1065.27828528',
#   'vwap': '0.00074552'},
#  {'close': '0.00074325',
#   'confirmed': True,
#   'high': '0.00074325',
#   'low': '0.00074325',
#   'open': '0.00074325',
#   'priceVolume': '0.01560825',
#   'timestamp': 1516315200000,
#   'volume': '21.00000000',
#   'vwap': '0.00074325'},
#  {'close': '0.00074200',
#   'confirmed': True,
#   'high': '0.00074789',
#   'low': '0.00074200',
#   'open': '0.00074789',
#   'priceVolume': '0.04726320',
#   'timestamp': 1516314900000,
#   'volume': '63.53179302',
#   'vwap': '0.00074393'},
#  {'close': '0.00075823',
#   'confirmed': True,
#   'high': '0.00075823',
#   'low': '0.00074332',
#   'open': '0.00074677',
#   'priceVolume': '2.02555909',
#   'timestamp': 1516314600000,
#   'volume': '2708.47364315',
#   'vwap': '0.00074786'}]

# %%
waves = pd.DataFrame(r7)

# %%
waves
# Out:
#          close  confirmed        high         low        open priceVolume  \
# 0   0.00073544       True  0.00073544  0.00073443  0.00073443  0.01451969
# 1   0.00073309       True  0.00073309  0.00073309  0.00073309  0.07330282
# 2   0.00073201       True  0.00073201  0.00073201  0.00073201  0.00991107
# 3   0.00073284       True  0.00073284  0.00073284  0.00073284  0.00018995
# 4   0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 5   0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 6   0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 7   0.00073128       True  0.00073266  0.00073128  0.00073266  0.04709781
# 8   0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 9   0.00073430       True  0.00073430  0.00072641  0.00072641  0.00218702
# 10  0.00072620       True  0.00073000  0.00072620  0.00073000  0.13424130
# 11  0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 12  0.00073555       True  0.00073555  0.00073068  0.00073068  0.17152005
# 13  0.00073375       True  0.00073375  0.00073375  0.00073375  0.01498225
# 14  0.00073479       True  0.00073479  0.00073479  0.00073479  0.00073479
# 15  0.00073463       True  0.00073463  0.00073463  0.00073463  0.32527107
# 16  0.00073675       True  0.00073675  0.00072900  0.00072900  0.10992360
# 17  0.00073035       True  0.00073035  0.00073035  0.00073035  0.00146070
# 18  0.00073149       True  0.00073290  0.00073149  0.00073211  0.27573811
# 19  0.00073246       True  0.00073246  0.00072300  0.00072774  0.59487996
# 20  0.00073180       True  0.00073180  0.00072661  0.00072661  0.20345435
# 21  0.00072766       True  0.00073329  0.00072766  0.00073329  0.11742201
# 22  0.00073220       True  0.00073220  0.00072342  0.00072523  0.17125844
# 23  0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 24  0.00072651       True  0.00072651  0.00072651  0.00072651  0.10800002
# 25  0.00072416       True  0.00072434  0.00072416  0.00072434  0.03932592
# 26  0.00072225       True  0.00072801  0.00072225  0.00072801  0.41239315
# 27  0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 28  0.00073204       True  0.00073204  0.00073082  0.00073204  0.11651277
# 29  0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# ..         ...        ...         ...         ...         ...         ...
# 70  0.00074456       True  0.00074509  0.00074131  0.00074509  0.07953303
# 71  0.00074509       True  0.00074509  0.00074509  0.00074509  0.40914861
# 72  0.00074377       True  0.00074509  0.00074377  0.00074509  0.11582239
# 73  0.00074509       True  0.00074562  0.00074508  0.00074562  0.06859822
# 74  0.00074542       True  0.00074542  0.00074504  0.00074504  0.14390474
# 75  0.00073440       True  0.00073440  0.00073440  0.00073440  0.73440000
# 76  0.00073900       True  0.00073900  0.00073900  0.00073900  0.04849999
# 77  0.00073900       True  0.00073930  0.00073420  0.00073878  0.67005061
# 78  0.00073930       True  0.00074000  0.00073930  0.00074000  0.13172278
# 79  0.00074563       True  0.00074563  0.00074563  0.00074563  0.07881203
# 80  0.00000000       True  0.00000000  0.00000000  0.00000000  0.00000000
# 81  0.00074232       True  0.00074232  0.00074232  0.00074232  0.00012599
# 82  0.00073800       True  0.00073800  0.00073800  0.00073800  0.07896600
# 83  0.00074205       True  0.00074205  0.00073700  0.00073983  0.18822863
# 84  0.00073983       True  0.00074074  0.00073983  0.00074074  0.01584374
# 85  0.00074485       True  0.00074521  0.00074307  0.00074307  0.23615480
# 86  0.00073822       True  0.00073822  0.00073420  0.00073820  1.49022919
# 87  0.00073988       True  0.00074679  0.00073988  0.00074550  0.43183807
# 88  0.00074042       True  0.00074042  0.00074042  0.00074042  0.00148084
# 89  0.00074764       True  0.00074764  0.00074764  0.00074764  0.14952800
# 90  0.00074042       True  0.00074050  0.00074042  0.00074050  0.00971824
# 91  0.00074765       True  0.00074765  0.00074150  0.00074150  0.21221870
# 92  0.00074259       True  0.00074770  0.00074259  0.00074770  0.22658320
# 93  0.00074042       True  0.00074454  0.00074042  0.00074200  0.60382269
# 94  0.00074459       True  0.00074593  0.00074265  0.00074265  0.11670607
# 95  0.00074265       True  0.00074770  0.00074265  0.00074770  0.11413052
# 96  0.00074507       True  0.00074770  0.00074182  0.00074770  0.79418626
# 97  0.00074325       True  0.00074325  0.00074325  0.00074325  0.01560825
# 98  0.00074200       True  0.00074789  0.00074200  0.00074789  0.04726320
# 99  0.00075823       True  0.00075823  0.00074332  0.00074677  2.02555909
#
#         timestamp         volume        vwap
# 0   1516344300000    19.75495240  0.00073499
# 1   1516344000000    99.99158357  0.00073309
# 2   1516343700000    13.53952995  0.00073201
# 3   1516343400000     0.25920745  0.00073284
# 4   1516343100000     0.00000000  0.00000000
# 5   1516342800000     0.00000000  0.00000000
# 6   1516342500000     0.00000000  0.00000000
# 7   1516342200000    64.28683098  0.00073262
# 8   1516341900000     0.00000000  0.00000000
# 9   1516341600000     2.98917097  0.00073165
# 10  1516341300000   184.28095855  0.00072846
# 11  1516341000000     0.00000000  0.00000000
# 12  1516340700000   233.67536981  0.00073401
# 13  1516340400000    20.41875298  0.00073375
# 14  1516340100000     1.00000000  0.00073479
# 15  1516339800000   442.76856866  0.00073463
# 16  1516339500000   150.32492975  0.00073124
# 17  1516339200000     2.00000000  0.00073035
# 18  1516338900000   376.54223571  0.00073229
# 19  1516338600000   814.91522757  0.00072999
# 20  1516338300000   279.29761953  0.00072845
# 21  1516338000000   160.22871833  0.00073284
# 22  1516337700000   236.05249266  0.00072551
# 23  1516337400000     0.00000000  0.00000000
# 24  1516337100000   148.65594417  0.00072651
# 25  1516336800000    54.29883279  0.00072425
# 26  1516336500000   568.59855003  0.00072528
# 27  1516336200000     0.00000000  0.00000000
# 28  1516335900000   159.19873161  0.00073187
# 29  1516335600000     0.00000000  0.00000000
# ..            ...            ...         ...
# 70  1516323300000   106.87195195  0.00074419
# 71  1516323000000   549.12644110  0.00074509
# 72  1516322700000   155.61251050  0.00074430
# 73  1516322400000    92.05714340  0.00074517
# 74  1516322100000   193.09593061  0.00074525
# 75  1516321800000  1000.00000000  0.00073440
# 76  1516321500000    65.62922868  0.00073900
# 77  1516321200000   907.74315703  0.00073815
# 78  1516320900000   178.03263509  0.00073988
# 79  1516320600000   105.69859045  0.00074563
# 80  1516320300000     0.00000000  0.00000000
# 81  1516320000000     0.16973321  0.00074232
# 82  1516319700000   107.00000000  0.00073800
# 83  1516319400000   254.07118119  0.00074085
# 84  1516319100000    21.40525815  0.00074018
# 85  1516318800000   317.56176411  0.00074365
# 86  1516318500000  2028.07456939  0.00073480
# 87  1516318200000   582.80889254  0.00074096
# 88  1516317900000     2.00000000  0.00074042
# 89  1516317600000   200.00000000  0.00074764
# 90  1516317300000    13.12495734  0.00074044
# 91  1516317000000   283.87803932  0.00074757
# 92  1516316700000   303.37703434  0.00074687
# 93  1516316400000   813.86495884  0.00074192
# 94  1516316100000   156.71344976  0.00074471
# 95  1516315800000   153.44661078  0.00074378
# 96  1516315500000  1065.27828528  0.00074552
# 97  1516315200000    21.00000000  0.00074325
# 98  1516314900000    63.53179302  0.00074393
# 99  1516314600000  2708.47364315  0.00074786
#
# [100 rows x 9 columns]
